# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hilo
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | kavieng
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | cap malheureux
# Processing Record 7 of Set 1 | bhainsdehi
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | saskylakh
# Processing Record 11 of Set 1 | berdigestyakh
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | villa rica
# Processing Record 14 of Set 1 | sangar
# Processing Record 15 of Set 1 | neuquen
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 1 | saint-francois
# Processing Record 19 of Set 1 | cherskiy
# Processing Record 20 of Set 1 | camacha
# Processing Record 21 of Set 1 | tias
# Processing Record 22 of Set 1 | verkhniye tatyshly
# Processing Record 23 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | meulaboh
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | bowen
# Processing Record 30 of Set 1 | fortuna
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | roald
# Processing Record 33 of Set 1 | leningradskiy
# Processing Record 34 of Set 1 | constitucion
# Processing Record 35 of Set 1 | dong hoi
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | hasaki
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | aklavik
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | altay
# Processing Record 44 of Set 1 | te anau
# Processing Record 45 of Set 1 | namatanai
# Processing Record 46 of Set 1 | castro
# Processing Record 47 of Set 1 | kalmunai
# Processing Record 48 of Set 1 | luganville
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | mandalgovi
# Processing Record 1 of Set 2 | richards bay
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | morondava
# Processing Record 4 of Set 2 | sibolga
# Processing Record 5 of Set 2 | atuona
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | venado tuerto
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | broome
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | thompson
# Processing Record 15 of Set 2 | mirnyy
# Processing Record 16 of Set 2 | marawi
# Processing Record 17 of Set 2 | dzerzhinskoye
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | corinto
# Processing Record 20 of Set 2 | methoni
# Processing Record 21 of Set 2 | macara
# Processing Record 22 of Set 2 | oranjemund
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | kaohsiung
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | plettenberg bay
# Processing Record 27 of Set 2 | merauke
# Processing Record 28 of Set 2 | buala
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | maceio
# Processing Record 32 of Set 2 | urucara
# Processing Record 33 of Set 2 | airai
# Processing Record 34 of Set 2 | havoysund
# Processing Record 35 of Set 2 | lorengau
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | tawang
# Processing Record 38 of Set 2 | vardo
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | yellowknife
# Processing Record 42 of Set 2 | coquimbo
# Processing Record 43 of Set 2 | aswan
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 46 of Set 2 | sosnovo-ozerskoye
# Processing Record 47 of Set 2 | los llanos de aridane
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | waingapu
# Processing Record 50 of Set 2 | karratha
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | arroyos y esteros
# Processing Record 3 of Set 3 | pogranichnyy
# Processing Record 4 of Set 3 | cockburn town
# Processing Record 5 of Set 3 | mount gambier
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | erzin
# Processing Record 8 of Set 3 | sioux lookout
# Processing Record 9 of Set 3 | zonguldak
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | otofuke
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | georgetown
# Processing Record 14 of Set 3 | riyadh
# Processing Record 15 of Set 3 | flin flon
# Processing Record 16 of Set 3 | esperance
# Processing Record 17 of Set 3 | cayenne
# Processing Record 18 of Set 3 | wageningen
# Processing Record 19 of Set 3 | hobart
# Processing Record 20 of Set 3 | mataura
# Processing Record 21 of Set 3 | abu kamal
# Processing Record 22 of Set 3 | ternate
# Processing Record 23 of Set 3 | jalu
# Processing Record 24 of Set 3 | faanui
# Processing Record 25 of Set 3 | katsuura
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | tuatapere
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | wagga wagga
# Processing Record 31 of Set 3 | dunedin
# Processing Record 32 of Set 3 | chipinge
# Processing Record 33 of Set 3 | north marysville
# City not found. Skipping...
# Processing Record 34 of Set 3 | olenegorsk
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | jolo
# Processing Record 37 of Set 3 | carnarvon
# Processing Record 38 of Set 3 | koutsouras
# Processing Record 39 of Set 3 | nelson bay
# Processing Record 40 of Set 3 | tual
# Processing Record 41 of Set 3 | baruun-urt
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | oktyabrskiy
# Processing Record 44 of Set 3 | san patricio
# Processing Record 45 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 3 | carbonia
# Processing Record 47 of Set 3 | maragogi
# Processing Record 48 of Set 3 | port alfred
# Processing Record 49 of Set 3 | marzuq
# Processing Record 50 of Set 3 | margate
# Processing Record 1 of Set 4 | hermanus
# Processing Record 2 of Set 4 | kaitangata
# Processing Record 3 of Set 4 | avera
# Processing Record 4 of Set 4 | hobyo
# Processing Record 5 of Set 4 | ambilobe
# Processing Record 6 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 4 | jamestown
# Processing Record 8 of Set 4 | yanam
# Processing Record 9 of Set 4 | dicabisagan
# Processing Record 10 of Set 4 | dikson
# Processing Record 11 of Set 4 | vao
# Processing Record 12 of Set 4 | taltal
# Processing Record 13 of Set 4 | charters towers
# Processing Record 14 of Set 4 | bitung
# Processing Record 15 of Set 4 | olinda
# Processing Record 16 of Set 4 | baghmara
# Processing Record 17 of Set 4 | codrington
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | zhuhai
# Processing Record 20 of Set 4 | alofi
# Processing Record 21 of Set 4 | ovalle
# Processing Record 22 of Set 4 | uruburetama
# Processing Record 23 of Set 4 | kerema
# Processing Record 24 of Set 4 | chuy
# Processing Record 25 of Set 4 | port shepstone
# Processing Record 26 of Set 4 | wamba
# Processing Record 27 of Set 4 | williston
# Processing Record 28 of Set 4 | quepos
# Processing Record 29 of Set 4 | tabou
# Processing Record 30 of Set 4 | avarua
# Processing Record 31 of Set 4 | cape town
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | omboue
# Processing Record 34 of Set 4 | anadyr
# Processing Record 35 of Set 4 | orsk
# Processing Record 36 of Set 4 | pavullo nel frignano
# Processing Record 37 of Set 4 | sinnamary
# Processing Record 38 of Set 4 | kruisfontein
# Processing Record 39 of Set 4 | deputatskiy
# Processing Record 40 of Set 4 | filadelfia
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | pedasi
# Processing Record 43 of Set 4 | entebbe
# Processing Record 44 of Set 4 | bacolod
# Processing Record 45 of Set 4 | toungoo
# City not found. Skipping...
# Processing Record 46 of Set 4 | visnes
# Processing Record 47 of Set 4 | waipawa
# Processing Record 48 of Set 4 | ust-kulom
# Processing Record 49 of Set 4 | kedougou
# Processing Record 50 of Set 4 | ilam
# Processing Record 1 of Set 5 | walvis bay
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | yulara
# Processing Record 4 of Set 5 | show low
# Processing Record 5 of Set 5 | tucupita
# Processing Record 6 of Set 5 | yar-sale
# Processing Record 7 of Set 5 | kavaratti
# Processing Record 8 of Set 5 | kupang
# Processing Record 9 of Set 5 | soderhamn
# Processing Record 10 of Set 5 | grindavik
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | sao filipe
# Processing Record 13 of Set 5 | wanning
# Processing Record 14 of Set 5 | edgewater
# Processing Record 15 of Set 5 | witu
# Processing Record 16 of Set 5 | dedza
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | fairbanks
# Processing Record 20 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 5 | safranbolu
# Processing Record 22 of Set 5 | narsaq
# Processing Record 23 of Set 5 | aykhal
# Processing Record 24 of Set 5 | xining
# Processing Record 25 of Set 5 | doraha
# Processing Record 26 of Set 5 | mehamn
# Processing Record 27 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 5 | nantucket
# Processing Record 29 of Set 5 | alihe
# Processing Record 30 of Set 5 | vikulovo
# Processing Record 31 of Set 5 | inhambane
# Processing Record 32 of Set 5 | comodoro rivadavia
# Processing Record 33 of Set 5 | sobolevo
# Processing Record 34 of Set 5 | basoko
# Processing Record 35 of Set 5 | sola
# Processing Record 36 of Set 5 | sorland
# Processing Record 37 of Set 5 | segarcea
# Processing Record 38 of Set 5 | tasiilaq
# Processing Record 39 of Set 5 | bathsheba
# Processing Record 40 of Set 5 | krasnoarmeysk
# Processing Record 41 of Set 5 | mendi
# Processing Record 42 of Set 5 | san cristobal
# Processing Record 43 of Set 5 | zverinogolovskoye
# Processing Record 44 of Set 5 | souillac
# Processing Record 45 of Set 5 | matara
# Processing Record 46 of Set 5 | kahului
# Processing Record 47 of Set 5 | beringovskiy
# Processing Record 48 of Set 5 | acapulco
# Processing Record 49 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | geraldton
# Processing Record 2 of Set 6 | balkanabat
# Processing Record 3 of Set 6 | young
# Processing Record 4 of Set 6 | lufilufi
# Processing Record 5 of Set 6 | dillon
# Processing Record 6 of Set 6 | villaviciosa
# Processing Record 7 of Set 6 | barrow
# Processing Record 8 of Set 6 | lockhart
# Processing Record 9 of Set 6 | lebu
# Processing Record 10 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 6 | kununurra
# Processing Record 12 of Set 6 | simbahan
# Processing Record 13 of Set 6 | algiers
# Processing Record 14 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 15 of Set 6 | bukachacha
# Processing Record 16 of Set 6 | itaueira
# Processing Record 17 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 6 | yaan
# Processing Record 20 of Set 6 | calobre
# City not found. Skipping...
# Processing Record 21 of Set 6 | yuryevets
# Processing Record 22 of Set 6 | luderitz
# Processing Record 23 of Set 6 | camapua
# Processing Record 24 of Set 6 | kuri
# Processing Record 25 of Set 6 | kishtwar
# Processing Record 26 of Set 6 | fershampenuaz
# Processing Record 27 of Set 6 | arona
# Processing Record 28 of Set 6 | pevek
# Processing Record 29 of Set 6 | grand gaube
# Processing Record 30 of Set 6 | isangel
# Processing Record 31 of Set 6 | severo-kurilsk
# Processing Record 32 of Set 6 | alpena
# Processing Record 33 of Set 6 | rafaela
# Processing Record 34 of Set 6 | batagay
# Processing Record 35 of Set 6 | saint anthony
# Processing Record 36 of Set 6 | lauchhammer
# Processing Record 37 of Set 6 | singleton
# Processing Record 38 of Set 6 | bonfim
# Processing Record 39 of Set 6 | wuan
# Processing Record 40 of Set 6 | limon
# Processing Record 41 of Set 6 | salalah
# Processing Record 42 of Set 6 | saint-joseph
# Processing Record 43 of Set 6 | palmas de monte alto
# Processing Record 44 of Set 6 | pitimbu
# Processing Record 45 of Set 6 | gurun
# Processing Record 46 of Set 6 | rocha
# Processing Record 47 of Set 6 | uthal
# Processing Record 48 of Set 6 | poum
# Processing Record 49 of Set 6 | shimoda
# Processing Record 50 of Set 6 | awjilah
# Processing Record 1 of Set 7 | inta
# Processing Record 2 of Set 7 | itupiranga
# Processing Record 3 of Set 7 | garm
# City not found. Skipping...
# Processing Record 4 of Set 7 | namibe
# Processing Record 5 of Set 7 | shubarkuduk
# Processing Record 6 of Set 7 | kokopo
# Processing Record 7 of Set 7 | launceston
# Processing Record 8 of Set 7 | bereda
# Processing Record 9 of Set 7 | hay river
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | portland
# Processing Record 12 of Set 7 | yongan
# Processing Record 13 of Set 7 | okmulgee
# Processing Record 14 of Set 7 | juan aldama
# Processing Record 15 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 7 | chase
# Processing Record 17 of Set 7 | ca mau
# Processing Record 18 of Set 7 | coahuayana
# Processing Record 19 of Set 7 | chunoyar
# Processing Record 20 of Set 7 | krasnoselkup
# Processing Record 21 of Set 7 | sibu
# Processing Record 22 of Set 7 | flinders
# Processing Record 23 of Set 7 | kendari
# Processing Record 24 of Set 7 | salinopolis
# Processing Record 25 of Set 7 | bella union
# Processing Record 26 of Set 7 | broken hill
# Processing Record 27 of Set 7 | antofagasta
# Processing Record 28 of Set 7 | plouzane
# Processing Record 29 of Set 7 | vernon
# Processing Record 30 of Set 7 | male
# Processing Record 31 of Set 7 | faya
# Processing Record 32 of Set 7 | seguin
# Processing Record 33 of Set 7 | kutum
# Processing Record 34 of Set 7 | pauini
# Processing Record 35 of Set 7 | genc
# Processing Record 36 of Set 7 | berlevag
# Processing Record 37 of Set 7 | saint-pierre
# Processing Record 38 of Set 7 | kandrian
# Processing Record 39 of Set 7 | duyun
# Processing Record 40 of Set 7 | samarai
# Processing Record 41 of Set 7 | jumla
# Processing Record 42 of Set 7 | bonthe
# Processing Record 43 of Set 7 | mahon
# Processing Record 44 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 45 of Set 7 | la ronge
# Processing Record 46 of Set 7 | tucumcari
# Processing Record 47 of Set 7 | el alto
# Processing Record 48 of Set 7 | tilichiki
# Processing Record 49 of Set 7 | mora
# Processing Record 50 of Set 7 | calama
# Processing Record 1 of Set 8 | esmeraldas
# Processing Record 2 of Set 8 | ondorhaan
# City not found. Skipping...
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | guanay
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | leninskoye
# Processing Record 7 of Set 8 | saldanha
# Processing Record 8 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 8 | mozarlandia
# Processing Record 10 of Set 8 | okhotsk
# Processing Record 11 of Set 8 | lasa
# Processing Record 12 of Set 8 | semporna
# Processing Record 13 of Set 8 | namtsy
# Processing Record 14 of Set 8 | juba
# Processing Record 15 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 8 | talnakh
# Processing Record 17 of Set 8 | padang
# Processing Record 18 of Set 8 | quang ngai
# Processing Record 19 of Set 8 | wattegama
# Processing Record 20 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 8 | arti
# Processing Record 22 of Set 8 | dubti
# Processing Record 23 of Set 8 | sakaide
# Processing Record 24 of Set 8 | umm lajj
# Processing Record 25 of Set 8 | dingle
# Processing Record 26 of Set 8 | rio gallegos
# Processing Record 27 of Set 8 | presidencia roque saenz pena
# Processing Record 28 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 8 | mitsamiouli
# Processing Record 30 of Set 8 | pomabamba
# Processing Record 31 of Set 8 | manuk mangkaw
# Processing Record 32 of Set 8 | college
# Processing Record 33 of Set 8 | dalianwan
# Processing Record 34 of Set 8 | ola
# Processing Record 35 of Set 8 | kimbe
# Processing Record 36 of Set 8 | casper
# Processing Record 37 of Set 8 | lompoc
# Processing Record 38 of Set 8 | nemuro
# Processing Record 39 of Set 8 | dargaville
# Processing Record 40 of Set 8 | eenhana
# Processing Record 41 of Set 8 | havre-saint-pierre
# Processing Record 42 of Set 8 | niteroi
# Processing Record 43 of Set 8 | san jose de gracia
# Processing Record 44 of Set 8 | turkan
# Processing Record 45 of Set 8 | awbari
# Processing Record 46 of Set 8 | burica
# City not found. Skipping...
# Processing Record 47 of Set 8 | havelock
# Processing Record 48 of Set 8 | cabo san lucas
# Processing Record 49 of Set 8 | bud
# Processing Record 50 of Set 8 | umm kaddadah
# Processing Record 1 of Set 9 | torbay
# Processing Record 2 of Set 9 | nicoya
# Processing Record 3 of Set 9 | straumen
# Processing Record 4 of Set 9 | corowa
# Processing Record 5 of Set 9 | karwar
# Processing Record 6 of Set 9 | gulabpura
# Processing Record 7 of Set 9 | katakwi
# Processing Record 8 of Set 9 | korla
# Processing Record 9 of Set 9 | port lincoln
# Processing Record 10 of Set 9 | odweyne
# Processing Record 11 of Set 9 | opotiki
# Processing Record 12 of Set 9 | talesh
# City not found. Skipping...
# Processing Record 13 of Set 9 | at-bashi
# Processing Record 14 of Set 9 | manacapuru
# Processing Record 15 of Set 9 | yazman
# Processing Record 16 of Set 9 | upata
# Processing Record 17 of Set 9 | katha
# City not found. Skipping...
# Processing Record 18 of Set 9 | poya
# Processing Record 19 of Set 9 | maxixe
# Processing Record 20 of Set 9 | qianan
# Processing Record 21 of Set 9 | high level
# Processing Record 22 of Set 9 | santa maria
# Processing Record 23 of Set 9 | russell
# Processing Record 24 of Set 9 | cabedelo
# Processing Record 25 of Set 9 | ust-nera
# Processing Record 26 of Set 9 | palmas
# Processing Record 27 of Set 9 | maniitsoq
# Processing Record 28 of Set 9 | port arthur
# Processing Record 29 of Set 9 | wabash
# Processing Record 30 of Set 9 | pisco
# Processing Record 31 of Set 9 | tiznit
# Processing Record 32 of Set 9 | nkhotakota
# Processing Record 33 of Set 9 | port blair
# Processing Record 34 of Set 9 | porto novo
# Processing Record 35 of Set 9 | pontes e lacerda
# Processing Record 36 of Set 9 | srednekolymsk
# Processing Record 37 of Set 9 | adwa
# Processing Record 38 of Set 9 | aripuana
# Processing Record 39 of Set 9 | concordia
# Processing Record 40 of Set 9 | bayan
# Processing Record 41 of Set 9 | halifax
# Processing Record 42 of Set 9 | pandan
# Processing Record 43 of Set 9 | qaqortoq
# Processing Record 44 of Set 9 | prado
# Processing Record 45 of Set 9 | karlshamn
# Processing Record 46 of Set 9 | trunovskoye
# Processing Record 47 of Set 9 | waddan
# Processing Record 48 of Set 9 | vestmannaeyjar
# Processing Record 49 of Set 9 | westport
# Processing Record 50 of Set 9 | rancho palos verdes
# Processing Record 1 of Set 10 | anchorage
# Processing Record 2 of Set 10 | caconda
# Processing Record 3 of Set 10 | srivardhan
# Processing Record 4 of Set 10 | quatre cocos
# Processing Record 5 of Set 10 | aquiraz
# Processing Record 6 of Set 10 | assiniboia
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | henties bay
# Processing Record 9 of Set 10 | preobrazheniye
# Processing Record 10 of Set 10 | gasa
# Processing Record 11 of Set 10 | kidodi
# Processing Record 12 of Set 10 | constantine
# Processing Record 13 of Set 10 | bouna
# Processing Record 14 of Set 10 | mgandu
# Processing Record 15 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 16 of Set 10 | kovur
# Processing Record 17 of Set 10 | makakilo city
# Processing Record 18 of Set 10 | valparaiso
# Processing Record 19 of Set 10 | tezu
# Processing Record 20 of Set 10 | hukuntsi
# Processing Record 21 of Set 10 | warkworth
# Processing Record 22 of Set 10 | kinablangan
# Processing Record 23 of Set 10 | lagoa
# Processing Record 24 of Set 10 | ciudad bolivar
# Processing Record 25 of Set 10 | kurilsk
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | alyangula
# Processing Record 28 of Set 10 | bonavista
# Processing Record 29 of Set 10 | naze
# Processing Record 30 of Set 10 | egvekinot
# Processing Record 31 of Set 10 | moron
# Processing Record 32 of Set 10 | cabra
# Processing Record 33 of Set 10 | sovik
# Processing Record 34 of Set 10 | coihaique
# Processing Record 35 of Set 10 | emba
# Processing Record 36 of Set 10 | khash
# Processing Record 37 of Set 10 | almansa
# Processing Record 38 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 39 of Set 10 | nampula
# Processing Record 40 of Set 10 | ruwi
# Processing Record 41 of Set 10 | sao sebastiao
# Processing Record 42 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 43 of Set 10 | pocri
# Processing Record 44 of Set 10 | lengshuitan
# Processing Record 45 of Set 10 | ostrovnoy
# Processing Record 46 of Set 10 | pareora
# Processing Record 47 of Set 10 | bandarbeyla
# Processing Record 48 of Set 10 | pangody
# Processing Record 49 of Set 10 | san carlos
# Processing Record 50 of Set 10 | byron bay
# Processing Record 1 of Set 11 | yatou
# Processing Record 2 of Set 11 | oliveira dos brejinhos
# Processing Record 3 of Set 11 | pangkalanbuun
# Processing Record 4 of Set 11 | haines junction
# Processing Record 5 of Set 11 | killybegs
# Processing Record 6 of Set 11 | vila velha
# Processing Record 7 of Set 11 | pacifica
# Processing Record 8 of Set 11 | moramanga
# Processing Record 9 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 11 | keti bandar
# Processing Record 11 of Set 11 | kuytun
# Processing Record 12 of Set 11 | lakes entrance
# Processing Record 13 of Set 11 | ayan
# Processing Record 14 of Set 11 | san jose de guanipa
# Processing Record 15 of Set 11 | abashiri
# Processing Record 16 of Set 11 | erbaa
# Processing Record 17 of Set 11 | hibbing
# Processing Record 18 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 11 | rybnoye
# Processing Record 20 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 21 of Set 11 | yingcheng
# Processing Record 22 of Set 11 | tynda
# Processing Record 23 of Set 11 | bambanglipuro
# Processing Record 24 of Set 11 | poro
# Processing Record 25 of Set 11 | saint-augustin
# Processing Record 26 of Set 11 | tortoli
# Processing Record 27 of Set 11 | podyuga
# Processing Record 28 of Set 11 | novobirilyussy
# Processing Record 29 of Set 11 | kudahuvadhoo
# Processing Record 30 of Set 11 | maghama
# City not found. Skipping...
# Processing Record 31 of Set 11 | abnub
# Processing Record 32 of Set 11 | karaton
# Processing Record 33 of Set 11 | palana
# Processing Record 34 of Set 11 | goya
# Processing Record 35 of Set 11 | tripoli
# Processing Record 36 of Set 11 | beyneu
# Processing Record 37 of Set 11 | turukhansk
# Processing Record 38 of Set 11 | juneau
# Processing Record 39 of Set 11 | monticello
# Processing Record 40 of Set 11 | labuhan
# Processing Record 41 of Set 11 | sur
# Processing Record 42 of Set 11 | yakeshi
# Processing Record 43 of Set 11 | rosetta
# Processing Record 44 of Set 11 | antalaha
# Processing Record 45 of Set 11 | iqaluit
# Processing Record 46 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 11 | hohhot
# Processing Record 48 of Set 11 | paita
# Processing Record 49 of Set 11 | vila
# Processing Record 50 of Set 11 | chicama
# Processing Record 1 of Set 12 | krasnyy chikoy
# Processing Record 2 of Set 12 | nuevo progreso
# Processing Record 3 of Set 12 | dzilam gonzalez
# Processing Record 4 of Set 12 | lazaro cardenas
# Processing Record 5 of Set 12 | balkhash
# Processing Record 6 of Set 12 | gushikawa
# Processing Record 7 of Set 12 | khandyga
# Processing Record 8 of Set 12 | martapura
# Processing Record 9 of Set 12 | tunxi
# City not found. Skipping...
# Processing Record 10 of Set 12 | hovd
# Processing Record 11 of Set 12 | yasnyy
# Processing Record 12 of Set 12 | mana
# Processing Record 13 of Set 12 | beloha
# Processing Record 14 of Set 12 | arrecife
# Processing Record 15 of Set 12 | puerto escondido
# Processing Record 16 of Set 12 | nabire
# Processing Record 17 of Set 12 | kharp
# Processing Record 18 of Set 12 | bani
# Processing Record 19 of Set 12 | dakar
# Processing Record 20 of Set 12 | sagua la grande
# Processing Record 21 of Set 12 | morros
# Processing Record 22 of Set 12 | kropotkin
# Processing Record 23 of Set 12 | uvat
# Processing Record 24 of Set 12 | carutapera
# Processing Record 25 of Set 12 | logumkloster
# Processing Record 26 of Set 12 | greenville
# Processing Record 27 of Set 12 | san andres
# Processing Record 28 of Set 12 | balykshi
# Processing Record 29 of Set 12 | ouadda
# Processing Record 30 of Set 12 | kloulklubed
# Processing Record 31 of Set 12 | limanu
# Processing Record 32 of Set 12 | mpanda
# Processing Record 33 of Set 12 | candawaga
# City not found. Skipping...
# Processing Record 34 of Set 12 | valka
# Processing Record 35 of Set 12 | arkhara
# Processing Record 36 of Set 12 | moa
# Processing Record 37 of Set 12 | nome
# Processing Record 38 of Set 12 | orangeburg
# Processing Record 39 of Set 12 | davila
# Processing Record 40 of Set 12 | nioki
# Processing Record 41 of Set 12 | luwuk
# Processing Record 42 of Set 12 | iquique
# Processing Record 43 of Set 12 | goundam
# Processing Record 44 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 45 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 12 | ostersund
# Processing Record 47 of Set 12 | soeng sang
# Processing Record 48 of Set 12 | mildura
# Processing Record 49 of Set 12 | gardez
# Processing Record 50 of Set 12 | mugur-aksy
# Processing Record 1 of Set 13 | svetlaya
# Processing Record 2 of Set 13 | urfa
# City not found. Skipping...
# Processing Record 3 of Set 13 | sao joao da barra
# Processing Record 4 of Set 13 | nouadhibou
# Processing Record 5 of Set 13 | hofn
# Processing Record 6 of Set 13 | souris
# Processing Record 7 of Set 13 | praya
# Processing Record 8 of Set 13 | syracuse
# Processing Record 9 of Set 13 | khuzdar
# Processing Record 10 of Set 13 | bodmin
# Processing Record 11 of Set 13 | laguna
# Processing Record 12 of Set 13 | yellandu
# Processing Record 13 of Set 13 | tadine
# Processing Record 14 of Set 13 | mbaiki
# Processing Record 15 of Set 13 | foam lake
# Processing Record 16 of Set 13 | kannur
# Processing Record 17 of Set 13 | hutchinson
# Processing Record 18 of Set 13 | canton
# Processing Record 19 of Set 13 | mayumba
# Processing Record 20 of Set 13 | verkhnevilyuysk
# Processing Record 21 of Set 13 | eureka
# Processing Record 22 of Set 13 | ormara
# Processing Record 23 of Set 13 | redmond
# Processing Record 24 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 13 | lilongwe
# Processing Record 27 of Set 13 | queanbeyan
# Processing Record 28 of Set 13 | marystown
# Processing Record 29 of Set 13 | espanola
# Processing Record 30 of Set 13 | mount isa
# Processing Record 31 of Set 13 | guerrero negro
# Processing Record 32 of Set 13 | eyl
# Processing Record 33 of Set 13 | chapleau
# Processing Record 34 of Set 13 | tagusao
# Processing Record 35 of Set 13 | praia da vitoria
# Processing Record 36 of Set 13 | koumac
# Processing Record 37 of Set 13 | tazovskiy
# Processing Record 38 of Set 13 | sechura
# Processing Record 39 of Set 13 | euclides da cunha
# Processing Record 40 of Set 13 | abalak
# Processing Record 41 of Set 13 | kuusankoski
# Processing Record 42 of Set 13 | puerto maldonado
# Processing Record 43 of Set 13 | kushmurun
# Processing Record 44 of Set 13 | shelburne
# Processing Record 45 of Set 13 | san quintin
# Processing Record 46 of Set 13 | muros
# Processing Record 47 of Set 13 | mackay
# Processing Record 48 of Set 13 | sabzevar
# Processing Record 49 of Set 13 | muriae
# Processing Record 50 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 1 of Set 14 | nador
# Processing Record 2 of Set 14 | pochutla
# Processing Record 3 of Set 14 | erzincan
# Processing Record 4 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 14 | lahaina
# Processing Record 6 of Set 14 | ilebo
# Processing Record 7 of Set 14 | sambava
# Processing Record 8 of Set 14 | teplyk
# Processing Record 9 of Set 14 | sistranda
# Processing Record 10 of Set 14 | katherine
# Processing Record 11 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 12 of Set 14 | griffith
# Processing Record 13 of Set 14 | fomboni
# Processing Record 14 of Set 14 | front royal
# Processing Record 15 of Set 14 | goma
# Processing Record 16 of Set 14 | boueni
# Processing Record 17 of Set 14 | svetlogorsk
# Processing Record 18 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 14 | nizhniy kuranakh
# Processing Record 20 of Set 14 | marsh harbour
# Processing Record 21 of Set 14 | jodhpur
# Processing Record 22 of Set 14 | carupano
# Processing Record 23 of Set 14 | trelew
# Processing Record 24 of Set 14 | qasigiannguit
# Processing Record 25 of Set 14 | wukari
# Processing Record 26 of Set 14 | naushki
# Processing Record 27 of Set 14 | asmara
# Processing Record 28 of Set 14 | nisia floresta
# Processing Record 29 of Set 14 | oytal
# Processing Record 30 of Set 14 | ati
# Processing Record 31 of Set 14 | susaki
# Processing Record 32 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 14 | ariquemes
# Processing Record 34 of Set 14 | wajima
# Processing Record 35 of Set 14 | hobe sound
# Processing Record 36 of Set 14 | dunkirk
# Processing Record 37 of Set 14 | arlit
# Processing Record 38 of Set 14 | khani
# Processing Record 39 of Set 14 | tsiroanomandidy
# Processing Record 40 of Set 14 | rio grande
# Processing Record 41 of Set 14 | muravlenko
# Processing Record 42 of Set 14 | whyalla
# Processing Record 43 of Set 14 | sungai padi
# Processing Record 44 of Set 14 | mahanoro
# Processing Record 45 of Set 14 | calvinia
# Processing Record 46 of Set 14 | west bay
# Processing Record 47 of Set 14 | puri
# Processing Record 48 of Set 14 | coacoatzintla
# Processing Record 49 of Set 14 | kafanchan
# Processing Record 50 of Set 14 | galle
# Processing Record 1 of Set 15 | santiago del estero
# Processing Record 2 of Set 15 | panaba
# Processing Record 3 of Set 15 | chanhassen
# Processing Record 4 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 15 | buraydah
# Processing Record 6 of Set 15 | sept-iles
# Processing Record 7 of Set 15 | dalbandin
# Processing Record 8 of Set 15 | norsup
# Processing Record 9 of Set 15 | hammerfest
# Processing Record 10 of Set 15 | kasra
# City not found. Skipping...
# Processing Record 11 of Set 15 | ruteng
# Processing Record 12 of Set 15 | muisne
# Processing Record 13 of Set 15 | moree
# Processing Record 14 of Set 15 | consolacion del sur
# Processing Record 15 of Set 15 | uray
# Processing Record 16 of Set 15 | batticaloa
# Processing Record 17 of Set 15 | podor
# Processing Record 18 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 15 | kuruman
# Processing Record 20 of Set 15 | wilmington
# Processing Record 21 of Set 15 | karasjok
# Processing Record 22 of Set 15 | barhi
# Processing Record 23 of Set 15 | dalvik
# Processing Record 24 of Set 15 | san jose
# Processing Record 25 of Set 15 | dhidhdhoo
# Processing Record 26 of Set 15 | vila franca do campo
# Processing Record 27 of Set 15 | banda aceh
# Processing Record 28 of Set 15 | vinh
# Processing Record 29 of Set 15 | los alamos
# Processing Record 30 of Set 15 | pathein
# Processing Record 31 of Set 15 | la romana
# Processing Record 32 of Set 15 | soc trang
# Processing Record 33 of Set 15 | kirakira
# Processing Record 34 of Set 15 | port-gentil
# Processing Record 35 of Set 15 | inhapim
# Processing Record 36 of Set 15 | port hardy
# Processing Record 37 of Set 15 | loreto
# Processing Record 38 of Set 15 | yithion
# City not found. Skipping...
# Processing Record 39 of Set 15 | canico
# Processing Record 40 of Set 15 | barra do bugres
# Processing Record 41 of Set 15 | taoudenni
# Processing Record 42 of Set 15 | port macquarie
# Processing Record 43 of Set 15 | hervey bay
# Processing Record 44 of Set 15 | tautira
# Processing Record 45 of Set 15 | domoni
# Processing Record 46 of Set 15 | rabo de peixe
# Processing Record 47 of Set 15 | opuwo
# Processing Record 48 of Set 15 | port hedland
# Processing Record 49 of Set 15 | pudozh
# Processing Record 50 of Set 15 | bajil
# Processing Record 1 of Set 16 | acarau
# Processing Record 2 of Set 16 | cotonou
# Processing Record 3 of Set 16 | kaeo
# Processing Record 4 of Set 16 | sao joao de pirabas
# Processing Record 5 of Set 16 | chake chake
# Processing Record 6 of Set 16 | la rioja
# Processing Record 7 of Set 16 | dourbali
# Processing Record 8 of Set 16 | socorro
# Processing Record 9 of Set 16 | sibenik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hilo      US  19.7297 -155.0900     76.73        80          90
# 1         Ushuaia      AR -54.8000  -68.3000     42.46        70          20
# 2         Kavieng      PG  -2.5744  150.7967     80.98        75          12
# 3         Rikitea      PF -23.1203 -134.9692     69.08        63         100
# 4        Khatanga      RU  71.9667  102.5000     65.59        63          89
# 5  Cap Malheureux      MU -19.9842   57.6142     70.29        79          12
# 6      Bhainsdehi      IN  21.6467   77.6325     70.92        91         100
# 7    Punta Arenas      CL -53.1500  -70.9167     44.71        76          75
# 8        Cidreira      BR -30.1811  -50.2056     61.56        68           4
# 9       Saskylakh      RU  71.9167  114.0833     68.20        44           0
#
#    Wind Speed Current Description
# 0        5.75          light rain
# 1        5.75          few clouds
# 2        7.54          few clouds
# 3       22.84     overcast clouds
# 4        8.50     overcast clouds
# 5        7.00          light rain
# 6        9.46     overcast clouds
# 7       16.11       broken clouds
# 8        6.29           clear sky
# 9        7.49           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
